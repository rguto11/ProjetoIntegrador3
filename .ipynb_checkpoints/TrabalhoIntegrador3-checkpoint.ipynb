# %% [markdown]
# # Trabalho Prático Integrador 3

# %% [markdown]
# ### Enunciado
#
# Neste Trabalho Prático os alunos devem escolher com qual conjunto de dados trabalhar para resolver um problema de classificação com alguns dos modelos apresentados no curso.
#
# Objetivos:
# * Selecionar os dados para modelar. Justificar a escolha.
# * Treinar pelo menos três modelos de classificação diferentes nesses dados.
# * Avaliar o desempenho dos modelos e comparar vantagens e desvantagens de cada um.
# * Determinar a importância dos recursos incluídos na previsão. Interpretar.

# %% [markdown]
# ### Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ### Importando a base de dados

# %%
Data = pd.read_csv('Data/water_potability.csv')
Data.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
Data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# ### Renomeando as colunas para o Português

# %%
Data = Data.rename(columns={'Hardness' :  'Dureza',
                     'Solids'          :  'Sólidos',
                     'Chloramines'     :  'Cloraminas',
                     'Sulfate'         :  'Sulfato',
                     'Conductivity'    :  'Condutividade',
                     'Organic_carbon'  :  'Carbono organico',
                     'Trihalomethanes' :  'Trialometanos',
                     'Turbidity'       :  'Turbidez',
                     'Potability'      :  'Potabilidade'})

Data.head()
# Out:
#          ph      Dureza       Sólidos  Cloraminas     Sulfato  Condutividade  \
# 0       NaN  204.890455  20791.318981    7.300212  368.516441     564.308654
# 1  3.716080  129.422921  18630.057858    6.635246         NaN     592.885359
# 2  8.099124  224.236259  19909.541732    9.275884         NaN     418.606213
# 3  8.316766  214.373394  22018.417441    8.059332  356.886136     363.266516
# 4  9.092223  181.101509  17978.986339    6.546600  310.135738     398.410813
#
#    Carbono organico  Trialometanos  Turbidez  Potabilidade
# 0         10.379783      86.990970  2.963135             0
# 1         15.180013      56.329076  4.500656             0
# 2         16.868637      66.420093  3.055934             0
# 3         18.436524     100.341674  4.628771             0
# 4         11.558279      31.997993  4.075075             0

# %% [markdown]
# ### Verificando se há valor nulo

# %% [markdown]
# * Achamos um valor com ph valendo 0, portanto substituimos ele para ficar NaN e a gente filtrar junto com todos os outros NaN

# %%
a = Data.ph
a.replace(0,np.NaN,inplace = True)

# %%
Data.isnull().sum()
# Out:
# ph                  492
# Dureza                0
# Sólidos               0
# Cloraminas            0
# Sulfato             781
# Condutividade         0
# Carbono organico      0
# Trialometanos       162
# Turbidez              0
# Potabilidade          0
# dtype: int64

# %%
(Data.isnull().sum()/len(Data))*100

#porcentagem de NaN
# Out:
# ph                  15.018315
# Dureza               0.000000
# Sólidos              0.000000
# Cloraminas           0.000000
# Sulfato             23.840049
# Condutividade        0.000000
# Carbono organico     0.000000
# Trialometanos        4.945055
# Turbidez             0.000000
# Potabilidade         0.000000
# dtype: float64

# %% [markdown]
# ### Limpando o dataset

# %% [markdown]
# * Para substituir todos os NaN, nós dividimos o dataset original em dois dataframes: um com a potabilidade igual a um e outro com a potabilidade igual a zero. Nos dois, nós pegamos o valor correspondente a mediana de cada feature que a gente queria alterar e substituimos nos respectivos NaN das features correspondentes. E logo depois concatenamos os dois dataframes e fizemos um dataset para analisar, sem nenhum NaN.

# %% [markdown]
#  * ***Algumas observações:***

# %% [markdown]
# * De acordo com a Agência de Proteção Ambiental (EPA), o valor máximo de Trialometano permitido na água é de100ug/L e 66.4mg/l. (<http://sanepar.com.br/sanepar/sanare/v17/TRIHALOMETANOS.htm>)

# %% [markdown]
# * De acordo com o Ministério da Saúde, o valor máximo de Sulfato na água é de 250mg/L. (<https://bvsms.saude.gov.br/bvs/saudelegis/gm/2004/prt0518_25_03_2004.html>)

# %% [markdown]
# * A recomendação é que o Ph esteja de 6 à 9.5

# %% [markdown]
# ----

# %% [markdown]
# * Analisando a mediana de trialometano

# %%
p1t = Data[Data.Potabilidade == 1]
p1t.Trialometanos.describe()
p1t.Trialometanos.median()
# Out:
# 66.6782137100115

# %%
p0t = Data[Data.Potabilidade == 0]
p0t.Trialometanos.describe()
p0t.Trialometanos.median()
# Out:
# 66.54219804427565

# %% [markdown]
# ----

# %% [markdown]
# * Analisando a mediana de sulfato

# %%
p1s = Data[Data.Potabilidade == 1]
p1s.Sulfato.describe()
p1s.Sulfato.median()
# Out:
# 331.8381671295742

# %%
p0s = Data[Data.Potabilidade == 0]
p0s.Sulfato.describe()
p0s.Sulfato.median()
# Out:
# 333.38942610169323

# %% [markdown]
# ----

# %% [markdown]
# * Analisando a mediana de ph

# %%
p1p = Data[Data.Potabilidade == 1]
p1p.ph.describe()
p1p.ph.median()
# Out:
# 7.036752103833548

# %%
p0s = Data[Data.Potabilidade == 0]
p0s.ph.describe()
p0s.ph.median()
# Out:
# 7.038092305552901

# %% [markdown]
# * Substituindo os NaN :

# %%
df = Data[Data.Potabilidade==1]
df.Trialometanos.fillna(value = df.Trialometanos.median(), inplace=True)
df.Sulfato.fillna(value = df.Sulfato.median(), inplace=True)
df.ph.fillna(value = df.ph.median(), inplace=True)
dff = Data[Data.Potabilidade==0]
dff.Trialometanos.fillna(value = dff.Trialometanos.median(), inplace=True)
dff.Sulfato.fillna(value = dff.Sulfato.median(), inplace=True)
dff.ph.fillna(value = dff.ph.median(), inplace=True)
Data = pd.concat([df,dff],axis = 0)
Data
# Out:
# C:\Users\RedRagon\AppData\Local\Temp\ipykernel_7596\2034626617.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Trialometanos.fillna(value = df.Trialometanos.median(), inplace=True)
# C:\Users\RedRagon\AppData\Local\Temp\ipykernel_7596\2034626617.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Sulfato.fillna(value = df.Sulfato.median(), inplace=True)
# C:\Users\RedRagon\AppData\Local\Temp\ipykernel_7596\2034626617.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ph.fillna(value = df.ph.median(), inplace=True)
# C:\Users\RedRagon\AppData\Local\Temp\ipykernel_7596\2034626617.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff.Trialometanos.fillna(value = dff.Trialometanos.median(), inplace=True)
# C:\Users\RedRagon\AppData\Local\Temp\ipykernel_7596\2034626617.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff.Sulfato.fillna(value = dff.Sulfato.median(), inplace=True)
# C:\Users\RedRagon\AppData\Local\Temp\ipykernel_7596\2034626617.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff.ph.fillna(value = dff.ph.median(), inplace=True)
#             ph      Dureza       Sólidos  Cloraminas     Sulfato  \
# 250   9.445130  145.805402  13168.529156    9.444471  310.583374
# 251   9.024845  128.096691  19859.676476    8.016423  300.150377
# 252   7.036752  169.974849  23403.637304    8.519730  331.838167
# 253   6.800119  242.008082  39143.403329    9.501695  187.170714
# 254   7.174135  203.408935  20401.102461    7.681806  287.085679
# ...        ...         ...           ...         ...         ...
# 3112  6.616731  195.096968  34277.760400    7.632639  333.389426
# 3113  7.734569  230.919506  21776.594455    6.908591  333.389426
# 3114  6.971577  185.906938  27959.987873    7.214510  349.743879
# 3115  4.709187  179.141018  22291.418577    6.774276  407.417977
# 3116  5.230003  176.714023  27971.891806    7.597981  413.914001
#
#       Condutividade  Carbono organico  Trialometanos  Turbidez  Potabilidade
# 250      592.659021          8.606397      77.577460  3.875165             1
# 251      451.143481         14.770863      73.778026  3.985251             1
# 252      475.573562         12.924107      50.861913  2.747313             1
# 253      376.456593         11.432466      73.777275  3.854940             1
# 254      315.549900         14.533510      74.405616  3.939896             1
# ...             ...               ...            ...       ...           ...
# 3112     417.465080         13.432557      47.945936  3.622379             0
# 3113     395.114961         15.033557      92.697369  3.821456             0
# 3114     414.067354         19.882917      36.179003  3.226349             0
# 3115     371.264843         18.186801      86.528627  3.860084             0
# 3116     440.355374         14.423614      72.837370  3.045612             0
#
# [3276 rows x 10 columns]

# %%
Data.isnull().sum()
# Out:
# ph                  0
# Dureza              0
# Sólidos             0
# Cloraminas          0
# Sulfato             0
# Condutividade       0
# Carbono organico    0
# Trialometanos       0
# Turbidez            0
# Potabilidade        0
# dtype: int64

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3276 entries, 250 to 3116
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ph                3276 non-null   float64
#  1   Dureza            3276 non-null   float64
#  2   Sólidos           3276 non-null   float64
#  3   Cloraminas        3276 non-null   float64
#  4   Sulfato           3276 non-null   float64
#  5   Condutividade     3276 non-null   float64
#  6   Carbono organico  3276 non-null   float64
#  7   Trialometanos     3276 non-null   float64
#  8   Turbidez          3276 non-null   float64
#  9   Potabilidade      3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 281.5 KB

# %% [markdown]
# Analisando o Dataset depois de tirar os NaN

# %%
sns.pairplot(Data, hue ='Potabilidade')

# %%
plt.figure(figsize=(10,7))
sns.heatmap(Data.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (4,6))
sns.heatmap(Data.corr()[['Potabilidade']], 
            annot = True
           );

# %% [markdown]
# ### Aplicando os Modelos de Classificação

# %% [markdown]
# ##### KNN (K Neighbors Classifier)

# %%
sc = StandardScaler()
# matriz de variáveis explicativas
X = Data.drop('Potabilidade', axis = 1)

# variável target
y = Data.Potabilidade


features = X.columns
X[features] = sc.fit_transform(X[features])
X.head()
# Out:
#            ph    Dureza   Sólidos  Cloraminas   Sulfato  Condutividade  \
# 250  1.617268 -1.538083 -1.008935    1.467103 -0.635327       2.059774
# 251  1.330307 -2.076756 -0.245735    0.564899 -0.923999       0.308598
# 252 -0.027119 -0.802885  0.158493    0.882875 -0.047225       0.610907
# 253 -0.188687  1.388257  1.953788    1.503255 -4.050053      -0.615610
# 254  0.066683  0.214129 -0.183979    0.353496 -1.285489      -1.369296
#
#      Carbono organico  Trialometanos  Turbidez
# 250         -1.716796       0.708523 -0.117423
# 251          0.146899       0.467558  0.023664
# 252         -0.411428      -0.985815 -1.562900
# 253         -0.862394       0.467510 -0.143344
# 254          0.075141       0.507360 -0.034463

# %%
# separa em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

print('Há', y_train.shape[0], 'dados de treino e', y_test.shape[0], 'dados de teste')
# Out:
# Há 2194 dados de treino e 1082 dados de teste

# %%
# instanciamos o modelo especificando o valor desejado de k com o argumento n_neighbors
knn = KNeighborsClassifier(n_neighbors = 19)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=19)

# %%
y_pred =  knn.predict(X_test)

# %%
# obtemos a matriz de confusão
MCKNN = confusion_matrix(y_test, y_pred)
MCKNN
# Out:
# array([[562,  72],
#        [348, 100]], dtype=int64)

# %%
KNN = round(accuracy_score(y_test, y_pred),2)
KNN
# Out:
# 0.61

# %%
score_knn = cross_val_score(knn, X, y, cv = 10)
score_knn
# Out:
# array([0.64329268, 0.625     , 0.64634146, 0.64634146, 0.65243902,
#        0.58841463, 0.58715596, 0.59938838, 0.62079511, 0.65443425])

# %%
KNN_cm = confusion_matrix(y_test, y_pred)
sns.heatmap(KNN_cm/np.sum(KNN_cm), annot = True, fmt = '0.2%', cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.89      0.73       634
#            1       0.58      0.22      0.32       448
#
#     accuracy                           0.61      1082
#    macro avg       0.60      0.55      0.53      1082
# weighted avg       0.60      0.61      0.56      1082

# %%
precision_knn = 0.58
recall_knn = 0.22
f1_score_knn = 0.32

# %% [markdown]
# * precision: Porcentagem de previsões positivas corretas em relação ao total de previsões positivas
# * recall: Porcentagem de previsões positivas corretas em relação ao total de positivos reais.
# * f1-score: Uma média harmônica ponderada de precisão e recall. Quanto mais próximo de 1, melhor o modelo.

# %% [markdown]
# 1. O Modelo previu que 58% das amostras de água são potáveis;
# 2. De todos as amostras de água que realmente era potável, o modelo só previu esse resultado corretamente para 22% deles;
# 3. F1-score = 0.32, como não é muito próximo de 1, isso nos diz que o modelo faz um trabalho ruim ao prever se a água é potável ou não;
# 4. 634 amostras de água não são potáveis e 448 são potáveis nos dados de teste.

# %% [markdown]
# ##### Naive Bayes

# %%
sc = StandardScaler()
# matriz de variáveis explicativas
X = Data.drop('Potabilidade', axis = 1)

# variável target
y = Data.Potabilidade


features = X.columns
X[features] = sc.fit_transform(X[features])
X.head()
# Out:
#            ph    Dureza   Sólidos  Cloraminas   Sulfato  Condutividade  \
# 250  1.617268 -1.538083 -1.008935    1.467103 -0.635327       2.059774
# 251  1.330307 -2.076756 -0.245735    0.564899 -0.923999       0.308598
# 252 -0.027119 -0.802885  0.158493    0.882875 -0.047225       0.610907
# 253 -0.188687  1.388257  1.953788    1.503255 -4.050053      -0.615610
# 254  0.066683  0.214129 -0.183979    0.353496 -1.285489      -1.369296
#
#      Carbono organico  Trialometanos  Turbidez
# 250         -1.716796       0.708523 -0.117423
# 251          0.146899       0.467558  0.023664
# 252         -0.411428      -0.985815 -1.562900
# 253         -0.862394       0.467510 -0.143344
# 254          0.075141       0.507360 -0.034463

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2194, 9)
# (1082, 9)
# (2194,)
# (1082,)

# %%
gnb = GaussianNB()

gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
GNB = round(accuracy_score(y_test, y_pred),2)
GNB
# Out:
# 0.6

# %%
score_gnb = cross_val_score(gnb, X, y, cv = 10)
score_gnb
# Out:
# array([0.60060976, 0.62195122, 0.70121951, 0.625     , 0.66158537,
#        0.50609756, 0.5351682 , 0.65749235, 0.6116208 , 0.60550459])

# %%
conf_mat = confusion_matrix(y_test, y_pred)

print('Confusion matrix\n\n', conf_mat)
# Out:
# Confusion matrix
#
#  [[562  72]
#  [357  91]]

# %%
sns.heatmap(conf_mat/np.sum(conf_mat), annot = True, fmt = '0.2%', cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.89      0.72       634
#            1       0.56      0.20      0.30       448
#
#     accuracy                           0.60      1082
#    macro avg       0.58      0.54      0.51      1082
# weighted avg       0.59      0.60      0.55      1082

# %%
precision_gnb = 0.56
recall_gnb = 0.20
f1_score_gnb = 0.30

# %% [markdown]
# 1. O Modelo previu que 61% das amostras de água são potáveis;
# 2. De todos as amostras de água que realmente era potável, o modelo só previu esse resultado corretamente para 20% deles;
# 3. F1-score = 0.30, como não é muito próximo de 1, isso nos diz que o modelo faz um trabalho ruim ao prever se a água é potável ou não;
# 4. 634 amostras de água não são potáveis e 448 são potáveis nos dados de teste.

# %% [markdown]
# ##### Regressão Logística

# %%
sc = StandardScaler()
# matriz de variáveis explicativas
X = Data.drop('Potabilidade', axis = 1)

# variável target
y = Data.Potabilidade


features = X.columns
X[features] = sc.fit_transform(X[features])
X.head()
# Out:
#            ph    Dureza   Sólidos  Cloraminas   Sulfato  Condutividade  \
# 250  1.617268 -1.538083 -1.008935    1.467103 -0.635327       2.059774
# 251  1.330307 -2.076756 -0.245735    0.564899 -0.923999       0.308598
# 252 -0.027119 -0.802885  0.158493    0.882875 -0.047225       0.610907
# 253 -0.188687  1.388257  1.953788    1.503255 -4.050053      -0.615610
# 254  0.066683  0.214129 -0.183979    0.353496 -1.285489      -1.369296
#
#      Carbono organico  Trialometanos  Turbidez
# 250         -1.716796       0.708523 -0.117423
# 251          0.146899       0.467558  0.023664
# 252         -0.411428      -0.985815 -1.562900
# 253         -0.862394       0.467510 -0.143344
# 254          0.075141       0.507360 -0.034463

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, stratify = y, random_state = 0)

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
lr = LogisticRegression(max_iter = 200)
lr.fit(X_train_std, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
LR = round(accuracy_score(y_train, lr.predict(X_train_std)),2)
LR
# Out:
# 0.61

# %%
score_lr = cross_val_score(lr, X, y, cv = 10)
score_lr
# Out:
# array([0.6097561 , 0.6097561 , 0.6097561 , 0.6097561 , 0.6097561 ,
#        0.6097561 , 0.6116208 , 0.60856269, 0.6116208 , 0.6116208 ])

# %%
sns.heatmap(confusion_matrix(y_train, lr.predict(X_train_std)), 
            annot = True, 
            fmt = '4d'
           )

plt.xlabel('Preditos')
plt.ylabel('Reais');

# %%
# verificamos que as proporções da variável target no treino e teste são correspondentes
y_train.mean(), y_test.mean()
# Out:
# (0.390154968094804, 0.3900184842883549)

# %%
# Histograma de probabilidades
sns.histplot(data = lr.predict_proba(X_train_std[y_train == 0])[ : , 1], 
             stat = 'density'
            )

sns.histplot(data = lr.predict_proba(X_train_std[y_train == 1])[ : , 1], 
             stat = 'density', 
             color = 'orange'
            )
ylim = plt.ylim()
plt.vlines(0.5, ylim[0], ylim[1])
plt.ylim(ylim)
plt.legend(['Threshold', 'Potabilidade = 0', 'Potabilidade = 1']);

# %%
threshold = 0.45
probs = lr.predict_proba(X_train_std)[:,1]
y_pred = probs > threshold

# %%
accuracy_score(y_train, y_pred)
# Out:
# 0.6089334548769371

# %%
sns.heatmap(confusion_matrix(y_train, y_pred), 
            annot = True, 
            fmt = '4d'
           )

plt.xlabel('Preditos')
plt.ylabel('Reais');

# %%
print(metrics.classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.99      0.76      1338
#            1       0.46      0.01      0.03       856
#
#     accuracy                           0.61      2194
#    macro avg       0.54      0.50      0.39      2194
# weighted avg       0.55      0.61      0.47      2194

# %%
precision_lr = 0.46
recall_lr = 0.01
f1_score_lr = 0.03

# %% [markdown]
# 1. O Modelo previu que 46% das amostras de água são potáveis;
# 2. De todos as amostras de água que realmente era potável, o modelo só previu esse resultado corretamente para 1% deles;
# 3. F1-score = 0.03, como não é muito próximo de 1, isso nos diz que o modelo faz um trabalho ruim ao prever se a água é potável ou não;
# 4. 1338 amostras de água não são potáveis e 856 são potáveis nos dados de teste.

# %% [markdown]
# ##### Árvore de Decisão (Decision Tree)

# %%
sc = StandardScaler()
# matriz de variáveis explicativas
X = Data.drop('Potabilidade', axis = 1)

# variável target
y = Data.Potabilidade


features = X.columns
X[features] = sc.fit_transform(X[features])
X.head()
# Out:
#            ph    Dureza   Sólidos  Cloraminas   Sulfato  Condutividade  \
# 250  1.617268 -1.538083 -1.008935    1.467103 -0.635327       2.059774
# 251  1.330307 -2.076756 -0.245735    0.564899 -0.923999       0.308598
# 252 -0.027119 -0.802885  0.158493    0.882875 -0.047225       0.610907
# 253 -0.188687  1.388257  1.953788    1.503255 -4.050053      -0.615610
# 254  0.066683  0.214129 -0.183979    0.353496 -1.285489      -1.369296
#
#      Carbono organico  Trialometanos  Turbidez
# 250         -1.716796       0.708523 -0.117423
# 251          0.146899       0.467558  0.023664
# 252         -0.411428      -0.985815 -1.562900
# 253         -0.862394       0.467510 -0.143344
# 254          0.075141       0.507360 -0.034463

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train_std,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtree.predict(X_test_std)

# %%
dt = round(accuracy_score(y_test, y_pred),2)
dt
# Out:
# 0.71

# %%
score_dtree = cross_val_score(dtree, X, y, cv = 10)
score_dtree
# Out:
# array([0.68902439, 0.69512195, 0.70731707, 0.68902439, 0.74085366,
#        0.69207317, 0.71865443, 0.6941896 , 0.71865443, 0.74923547])

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot = True, 
            fmt = '4d'
           )

plt.xlabel('Preditos')
plt.ylabel('Reais');

# %%
dtree_cm = confusion_matrix(y_test, y_pred)
sns.heatmap(dtree_cm/np.sum(dtree_cm), annot = True, fmt = '0.2%', cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77       634
#            1       0.68      0.58      0.63       448
#
#     accuracy                           0.71      1082
#    macro avg       0.71      0.70      0.70      1082
# weighted avg       0.71      0.71      0.71      1082

# %%
precision_dtree = 0.68
recall_dtree = 0.58
f1_score_dtree = 0.63

# %% [markdown]
# 1. O Modelo previu que 68% das amostras de água são potáveis;
# 2. De todos as amostras de água que realmente era potável, o modelo só previu esse resultado corretamente para 58% deles;
# 3. F1-score = 0.63, como é quase perto de 1, da para falar que é  um bom modelo para prever se a água é potável ou não;
# 4. 634 amostras de água não são potáveis e 448 são potáveis nos dados de teste.

# %% [markdown]
# ##### AdaBoost

# %%
sc = StandardScaler()
# matriz de variáveis explicativas
X = Data.drop('Potabilidade', axis = 1)

# variável target
y = Data.Potabilidade


features = X.columns
X[features] = sc.fit_transform(X[features])
X.head()
# Out:
#            ph    Dureza   Sólidos  Cloraminas   Sulfato  Condutividade  \
# 250  1.617268 -1.538083 -1.008935    1.467103 -0.635327       2.059774
# 251  1.330307 -2.076756 -0.245735    0.564899 -0.923999       0.308598
# 252 -0.027119 -0.802885  0.158493    0.882875 -0.047225       0.610907
# 253 -0.188687  1.388257  1.953788    1.503255 -4.050053      -0.615610
# 254  0.066683  0.214129 -0.183979    0.353496 -1.285489      -1.369296
#
#      Carbono organico  Trialometanos  Turbidez
# 250         -1.716796       0.708523 -0.117423
# 251          0.146899       0.467558  0.023664
# 252         -0.411428      -0.985815 -1.562900
# 253         -0.862394       0.467510 -0.143344
# 254          0.075141       0.507360 -0.034463

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 0)

# %%
abc = AdaBoostClassifier(n_estimators=50, learning_rate=1)

# %%
model = abc.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
ABC = round(accuracy_score(y_test, y_pred),2)
ABC
# Out:
# 0.73

# %%
score_cvabc = cross_val_score(abc, X, y, cv = 10)
score_cvabc.mean()
# Out:
# 0.7383838666368315

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot = True, 
            fmt = '4d'
           )

plt.xlabel('Preditos')
plt.ylabel('Reais');

# %%
abc_cm = confusion_matrix(y_test, y_pred)
sns.heatmap(abc_cm/np.sum(KNN_cm), annot = True, fmt = '0.2%', cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.92      0.80       635
#            1       0.81      0.47      0.59       447
#
#     accuracy                           0.73      1082
#    macro avg       0.76      0.69      0.70      1082
# weighted avg       0.75      0.73      0.72      1082

# %%
precision_abc = 0.81
recall_abc = 0.47
f1_score_abc = 0.59

# %% [markdown]
# 1. O Modelo previu que 81% das amostras de água são potáveis;
# 2. De todos as amostras de água que realmente era potável, o modelo só previu esse resultado corretamente para 47% deles;
# 3. F1-score = 0.59, como é quase perto de 1, da para falar que é  um bom modelo para prever se a água é potável ou não;
# 4. 635 amostras de água não são potáveis e 447 são potáveis nos dados de teste.

# %% [markdown]
# ### Comparando os Modelos

# %%
modelos = [
       [KNeighborsClassifier(), KNN, round(score_knn.mean(),2), precision_knn, recall_knn, f1_score_knn ],
       [GaussianNB(), GNB, round(score_gnb.mean(),2), precision_gnb, recall_gnb, f1_score_gnb],
       [LogisticRegression(), LR, round(score_lr.mean(),2), precision_lr, recall_lr, f1_score_lr],
       [DecisionTreeClassifier(),dt,round(score_dtree.mean(),2), precision_dtree, recall_dtree, f1_score_dtree],
       [AdaBoostClassifier(),ABC, round(score_cvabc.mean(),2), precision_abc, recall_abc, f1_score_abc]
       ]

df = pd.DataFrame(modelos, columns=['Modelo', 'Accuracy score', 'cross validation','precision','recall','f1 score'])
df
df.sort_values(by=['Accuracy score'], ascending=True).style.background_gradient(subset=['Accuracy score'])
# Out:
# <style type="text/css">
# #T_0b853_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0b853_row1_col1, #T_0b853_row2_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_0b853_row3_col1 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_0b853_row4_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0b853">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b853_level0_col0" class="col_heading level0 col0" >Modelo</th>
#       <th id="T_0b853_level0_col1" class="col_heading level0 col1" >Accuracy score</th>
#       <th id="T_0b853_level0_col2" class="col_heading level0 col2" >cross validation</th>
#       <th id="T_0b853_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_0b853_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_0b853_level0_col5" class="col_heading level0 col5" >f1 score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b853_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0b853_row0_col0" class="data row0 col0" >GaussianNB()</td>
#       <td id="T_0b853_row0_col1" class="data row0 col1" >0.600000</td>
#       <td id="T_0b853_row0_col2" class="data row0 col2" >0.610000</td>
#       <td id="T_0b853_row0_col3" class="data row0 col3" >0.610000</td>
#       <td id="T_0b853_row0_col4" class="data row0 col4" >0.200000</td>
#       <td id="T_0b853_row0_col5" class="data row0 col5" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0b853_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_0b853_row1_col0" class="data row1 col0" >KNeighborsClassifier()</td>
#       <td id="T_0b853_row1_col1" class="data row1 col1" >0.610000</td>
#       <td id="T_0b853_row1_col2" class="data row1 col2" >0.630000</td>
#       <td id="T_0b853_row1_col3" class="data row1 col3" >0.580000</td>
#       <td id="T_0b853_row1_col4" class="data row1 col4" >0.220000</td>
#       <td id="T_0b853_row1_col5" class="data row1 col5" >0.320000</td>
#     </tr>
#     <tr>
#       <th id="T_0b853_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b853_row2_col0" class="data row2 col0" >LogisticRegression()</td>
#       <td id="T_0b853_row2_col1" class="data row2 col1" >0.610000</td>
#       <td id="T_0b853_row2_col2" class="data row2 col2" >0.610000</td>
#       <td id="T_0b853_row2_col3" class="data row2 col3" >0.610000</td>
#       <td id="T_0b853_row2_col4" class="data row2 col4" >0.010000</td>
#       <td id="T_0b853_row2_col5" class="data row2 col5" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_0b853_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0b853_row3_col0" class="data row3 col0" >DecisionTreeClassifier()</td>
#       <td id="T_0b853_row3_col1" class="data row3 col1" >0.710000</td>
#       <td id="T_0b853_row3_col2" class="data row3 col2" >0.710000</td>
#       <td id="T_0b853_row3_col3" class="data row3 col3" >0.700000</td>
#       <td id="T_0b853_row3_col4" class="data row3 col4" >0.600000</td>
#       <td id="T_0b853_row3_col5" class="data row3 col5" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_0b853_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0b853_row4_col0" class="data row4 col0" >AdaBoostClassifier()</td>
#       <td id="T_0b853_row4_col1" class="data row4 col1" >0.730000</td>
#       <td id="T_0b853_row4_col2" class="data row4 col2" >0.740000</td>
#       <td id="T_0b853_row4_col3" class="data row4 col3" >0.810000</td>
#       <td id="T_0b853_row4_col4" class="data row4 col4" >0.470000</td>
#       <td id="T_0b853_row4_col5" class="data row4 col5" >0.590000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * Com todas as especificações dos modelos, além da cross validation, accuracy score, também temos: precision, recall, f1-score. Dito isso, o melhor modelo a ser usado é a Árvore de Decisão e o AdaBoost. O cross validation e o accuracy score são bons comparados com os outros modelos, além do precision, recall e o f1 score também serem bons
